# %%
import experiment_inference_synthetic_networks
# %matplotlib inline

# %%
filename1 = "results/agglomeration_test_April30/oldAgg_agglomerate_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)

# %%
filename2 = "results/agglomeration_test_April30/newAgg_agglomerate_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename2)

# %%
filename3 = "results/agglomeration_test_April30/newAggvarfixed_agglomerate_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename3)
