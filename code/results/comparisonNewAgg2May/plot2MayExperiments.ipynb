# %%
import experiment_inference_synthetic_networks
# %matplotlib inline

# %% [markdown]
# # FIRST PART - agglomeration results
# ## symmetric case

# %%
filename1 = "results/comparisonNewAgg2May/newAggvarfixed_1e-2noise_agglomerate_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)

# %%
filename2 = "results/comparisonNewAgg2May/oldAgg_1e-2noise_agglomerate_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename2)

# %% [markdown]
# Most of the improvement effect is due to providing a meaningful 'noise' effect (bug fixed!), but there is some extra gain as well from the better error estimate comparison
#
# ## Asymmetric case

# %%
filename3 = "results_asym/comparisonNewAgg2May/newAgg1e-2noise_agglomerate_inf_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename3)
# small blip around snr=2 -- instead of [3 5 7] [3 5 6 7] is found; boundary effect to be removed by forwarding higher level results?!

# %%
filename4 = "results_asym/comparisonNewAgg2May/oldAgg1e-2noise_agglomerate_inf_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename4)

# %% [markdown]
# ## Previous results

# %%
# For comparison -- older variant of the code before bugfix -- symmetric/ asym
filename5 =  "results/comparisonGMMvsKmeans/GMMsphere_agglomerate_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename5)
filename6 =  "results_asym/comparisonGMMvsKMeans/GMMsphere_agglomerate_inf_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename6)

# %% [markdown]
# # Second Part - complete agglomeration
# ## Symmetric case
# Asym case not done yet

# %%
filename7 =  "results/comparisonNewAgg2May/newAgg1e-2noise_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename7)
filename8 =  "results/comparisonNewAgg2May/oldAgg1e-2noise_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename8)

# %% [markdown]
# Improvements do not translate too well on first sight, we still have too many layers.
# A few thoughts:
# - Somewhat closer inspection shows that  the error pattern is actually quite different. The new agglomeration has often 'boundary errors' (instead of 9 it finds 10 and 9), the older variant has more erratic patterns.
# - We still do not have a good way to 'limit' the number of levels / prune out afterwards; one pass over the hier. may not be enough?
#
# However, compared to the pre-bugfix code, we already improve quite a bit int terms of overclustering

# %%
# For comparison -- older variant of the code before bugfix -- symmetric
filename7 =  "results/comparisonGMMvsKmeans/GMMsphere_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename7)
