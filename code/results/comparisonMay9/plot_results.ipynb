# %%
import experiment_inference_synthetic_networks
# %matplotlib inline

# %% [markdown]
# # Comparison new / old

# %%
filename1 = "results/comparisonMay9/newAgg1e-2noise_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)

# %%
filename2 = "results/comparisonMay9/newAgg2e-2noise_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename2)
