# %%
import experiment_inference_synthetic_networks
# %matplotlib inline
# Out:
# DendroPY not supported.

# %% [markdown]
# # Most recent variants - old overlap score

# %%
filename1 = "results/resultsMay17/v0.2experiments_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)

# %%
filename2 = "results_asym/resultsMay17/v0.2experiments_complete_inf_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename2)

# %% [markdown]
# # Most recent variants - nmi based overlap score

# %%
filename3 = "results/resultsMay17/v0.2experiments_nmi_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename3)

# %%
filename4 = "results_asym/resultsMay17/v0.2experiments_nmi_complete_inf_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename4)

# %% [markdown]
# Next steps:
# * check asym case and potentially make minimal adjustments. (no passing down option better results?)
# * improve / document code and remove superfluous cases. Python3?
# * speedup - do initial clustering via Bethe Hessian directly?
# * writing
