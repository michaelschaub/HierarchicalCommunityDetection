# %%
import plot_results

# %%
plot_results.plot_complete("28April_before_fix_new_code_complete_inf_sym_3_3.txt")

# %%
plot_results.plot_complete("28April_new_code_complete_inf_sym_3_3.txt")

# %%
plot_results.plot_complete("28April_new_code_complete_inf_asym_3_3.txt")
