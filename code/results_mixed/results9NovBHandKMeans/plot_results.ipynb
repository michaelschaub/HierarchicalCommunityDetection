# %%
import experiment_inference_synthetic_networks
import experiment_inference_synthetic_networks_asym
# %matplotlib inline
# Out:
# DendroPY not supported.

# %% [markdown]
# # Comparison row normalization vs not

# %%
filename1 = "results_mixed/results7Nov/resultsNov7_adjmi_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)
filename1 = "results_mixed/results9NovBHandKMeans/resultsNov9_adjmi_BHonly_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)
filename1 = "results_mixed/results9NovBHandKMeans/resultsNov9_adjmi_kmeans_complete_inf_sym_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)

# %%
filename1 = "results_mixed/results7Nov/resultsNov7_adjmi_complete_inf_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)
filename1 = "results_mixed/results9NovBHandKMeans/resultsNov9_adjmi_BHonly_asym_complete_inf_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)
filename1 = "results_mixed/results9NovBHandKMeans/resultsNov9_adjmi_kmeans_asym_complete_inf_3_3.txt"
experiment_inference_synthetic_networks.plot_complete(filename1)

# %% [markdown]
# Verdict
# * Bethe Hessian as model selection AND first step seems clearly preferable.
# * k-means vs non-k-means seems less of an influence (though GMM might be more stable); advantage k-means (?) relation to EEP formulation!?
