# %%
import plot_results
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Plot results of syn. network experiments

# %%
filename1 = "results_mixed/resultsDec18_updatedThres/resultsDec18_updatedThresIndep_complete_inf_sym_3_3.txt"
plot_results.plot_complete(filename1)
fig = plt.gcf()
fig.set_size_inches(4, 3)
fig.savefig('results_sym.svg', dpi=300)
filename1 = "results_mixed/resultsDec18_updatedThres/resultsDec18_updatedThresIndep_complete_inf_3_3.txt"
plot_results.plot_complete(filename1,title="Asymmetric")
fig = plt.gcf()
fig.set_size_inches(4, 3)
fig.savefig('results_asym.svg', dpi=300)
